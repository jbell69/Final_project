# %%
import pandas as pd
import re

# %%
#read in tables and print to see counts & columns. 
artists_full = pd.read_csv('artists_table_final.csv')
paintings_wip = pd.read_csv('paintings_wip.csv')


#read out object counts & unique counts - these are primary keys in the db so they all need to be unique
print(paintings_wip.Object_id.count())
print(paintings_wip.Object_id.nunique())
print("----------------")
print(artists_full.Artist_id.count())
print(artists_full.Artist_id.nunique())
# Out:
# 2819
# 2652
# ----------------
# 2299
# 2299

# %%
#paintings_wip has duplicate ids in it. This will mess up the primary key constraint in our database, so dedupe & read out to confirm
paintings_wip.drop_duplicates(subset='Object_id', keep = 'first', inplace=True)
print(paintings_wip.Object_id.count())
print(paintings_wip.Object_id.nunique())
# Out:
# 2652
# 2652

# %%
#We probably dropped a lot of artists when we dropped paintings outside the public domain, so we can consolidate our artist table to make our db more efficient
#This is important because we want to host on Heroku and therefore want to keep the database light. 

#read out artist_id into a list that we can use to filter our artist table
artist_list = paintings_wip.Artist_id.to_list()

#filter artist table
filter_in_paintings = artists_full.Artist_id.isin(artist_list)
artists_wip = artists_full[filter_in_paintings]

print(artists_wip.Artist_id.count())
print(artists_wip.Artist_id.nunique())
# Out:
# 983
# 983

# %%
artists_wip.head(10)
# Out:
#       Surname            First_name                       Full_name  \
# 0   Defeuille  Louis Benjamin Huber  Louis Benjamin Huber Defeuille
# 2     Unknown                blank_                         Unknown
# 4        Nini         Jean-Baptiste              Jean-Baptiste Nini
# 5     Sanford                    H.                      H. Sanford
# 6     Babcock            William P.              William P. Babcock
# 7      Stuart               Gilbert                  Gilbert Stuart
# 9       Inman                 Henry                     Henry Inman
# 10   La Farge                  John                   John La Farge
# 11      Ryder        Albert Pinkham            Albert Pinkham Ryder
# 12      Abbey          Edwin Austin              Edwin Austin Abbey
#
#     Birth_date     Death_date  Artist_id  \
# 0      Unknown  Unknown                0
# 2      Unknown        Unknown          2
# 4   1717           1786                3
# 5   1783           1822                4
# 6   1826           1899                5
# 7   1755           1828                6
# 9   1801           1846                8
# 10  1835           1910                9
# 11  1847           1917               10
# 12  1852           1911               11
#
#                                         image  \
# 0                    image could not be found
# 2                    image could not be found
# 4                    image could not be found
# 5                    image could not be found
# 6                    image could not be found
# 7          /wiki/File:Gilbert_Stuart_crop.jpg
# 9                    image could not be found
# 10    /wiki/File:Portrait_of_John_LaFarge.jpg
# 11        /wiki/File:Albert_Pinkham_Ryder.jpg
# 12  /wiki/File:Edwin_Austin_Abbey_cropped.jpg
#
#                                             Biography
# 0                        Biography could not be found
# 2                        Biography could not be found
# 4                        Biography could not be found
# 5                        Biography could not be found
# 6                        Biography could not be found
# 7   s foremost portraitists.[2] His best known wor...
# 9                        Biography could not be found
# 10  John La Farge (March 31, 1835 – November 14, 1...
# 11  Albert Pinkham Ryder (March 19, 1847 – March 2...
# 12  Edwin Austin Abbey RA (April 1, 1852\xa0– Augu...

# %%
#We have another problem in that our original 'scrape' of the artist images that we /could/ find was incorrect
#It's a file path to an image...NOT the actual hosted image path that we need in order to display it

#So I'll need to re-scrape for those who we originally found a wiki entry for. 
has_wiki = artists_wip.image != "image could not be found"

artists_for_scrape = artists_wip[has_wiki]

# %%
print("Artists we can scrape for: " + str(artists_for_scrape.Artist_id.count()))
# Out:
# Artists we can scrape for: 683

# %%
######### Scraper. I'm just repurposing most of the OG scraper from our ETL project. 
######### Let's do this. :P 

import requests
from bs4 import BeautifulSoup

results = []
error = []

limit = 20

for index, row in artists_for_scrape.iterrows():

    name = artists.loc[index,'Full_name']

    #url = input('SENT FROM USER REQUEST')
    url = 'https://en.wikipedia.org/wiki/'+ name
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    print('grabbing page for...' + name)

    try:
        header_artist_name = soup.find('h1', class_="firstHeading").text
        name_error = False
    except:
        header_artist_name = 'unfound' 
        name_error = True

    try: 
        artist_image_search = soup.find("a",{"class":"image"})
        artist_image_link = artist_image_search.findChild()
        img_src = artist_image_link["src"]
        artists_for_scrape.loc[index, 'Image_link'] = img_src
        image_error = False
    except:
        artist_image_link = 'unfound' 
        image_error = True
    
    print('Errors:' + str(name_error) + str(image_error))
    

print("Finished!")
# Out:
# grabbing page for...Gilbert Stuart
# Errors:FalseFalse
# grabbing page for...John La Farge
# Errors:FalseFalse
# grabbing page for...Albert Pinkham Ryder
# Errors:FalseFalse
# grabbing page for...Edwin Austin Abbey
# Errors:FalseFalse
# grabbing page for...Francis Alexander
# Errors:FalseFalse
# grabbing page for...John White Alexander
# Errors:FalseFalse
# grabbing page for...Washington Allston
# Errors:FalseFalse
# grabbing page for...Ezra Ames
# Errors:FalseFalse
# grabbing page for...Joseph Alexander Ames
# Errors:FalseFalse
# grabbing page for...Thomas Anshutz
# Errors:FalseFalse
# grabbing page for...John Woodhouse Audubon
# Errors:FalseFalse
# grabbing page for...Joseph Badger
# Errors:FalseFalse
# grabbing page for...W. H. Bean
# Errors:FalseTrue
# grabbing page for...J. Carroll Beckwith
# Errors:FalseFalse
# grabbing page for...Henry Benbridge
# Errors:FalseFalse
# grabbing page for...Albert Bierstadt
# Errors:FalseFalse
# grabbing page for...George Caleb Bingham
# Errors:FalseFalse
# grabbing page for...Robert Frederick Blum
# Errors:FalseFalse
# grabbing page for...David Gilmour Blythe
# Errors:FalseFalse
# grabbing page for...Alfred Thompson Bricher
# Errors:FalseFalse
# grabbing page for...George Loring Brown
# Errors:FalseFalse
# grabbing page for...John George Brown
# Errors:FalseFalse
# grabbing page for...Mather Brown
# Errors:FalseFalse
# grabbing page for...John William Casilear
# Errors:FalseFalse
# grabbing page for...Charles Robert Leslie
# Errors:FalseFalse
# grabbing page for...Francis William Edmonds
# Errors:FalseFalse
# grabbing page for...John Gadsby Chapman
# Errors:FalseFalse
# grabbing page for...Alonzo Chappel
# Errors:FalseFalse
# grabbing page for...William Merritt Chase
# Errors:FalseFalse
# grabbing page for...George Chinnery
# Errors:FalseFalse
# grabbing page for...Frederic Edwin Church
# Errors:FalseFalse
# grabbing page for...Thomas Cole
# Errors:FalseFalse
# grabbing page for...Samuel Colman
# Errors:FalseFalse
# grabbing page for...Nelson Cook
# Errors:FalseFalse
# grabbing page for...John Singleton Copley
# Errors:FalseFalse
# grabbing page for...Jasper Francis Cropsey
# Errors:FalseFalse
# grabbing page for...Robert S. Duncanson
# Errors:FalseFalse
# grabbing page for...William Dunlap
# Errors:FalseFalse
# grabbing page for...George Henry Durrie
# Errors:FalseFalse
# grabbing page for...Frank Duveneck
# Errors:FalseFalse
# grabbing page for...Thomas Eakins
# Errors:FalseFalse
# grabbing page for...Ralph Earl
# Errors:FalseFalse
# grabbing page for...Ralph E. W. Earl
# Errors:FalseFalse
# grabbing page for...Jacob Eichholtz
# Errors:FalseFalse
# grabbing page for...Charles Loring Elliott
# Errors:FalseFalse
# grabbing page for...Robert Feke
# Errors:FalseFalse
# grabbing page for...Erastus Salisbury Field
# Errors:FalseFalse
# grabbing page for...John F. Francis
# Errors:FalseFalse
# grabbing page for...James Frothingham
# Errors:FalseFalse
# grabbing page for...Robert Swain Gifford
# Errors:FalseFalse
# grabbing page for...Sanford Robinson Gifford
# Errors:FalseFalse
# grabbing page for...Henry Peters Gray
# Errors:FalseFalse
# grabbing page for...Seymour Joseph Guy
# Errors:FalseFalse
# grabbing page for...William Michael Harnett
# Errors:FalseFalse
# grabbing page for...William Stanley Haseltine
# Errors:FalseFalse
# grabbing page for...Robert Havell
# Errors:FalseFalse
# grabbing page for...George P. A. Healy
# Errors:FalseFalse
# grabbing page for...Edward Lamson Henry
# Errors:FalseFalse
# grabbing page for...John Hesselius
# Errors:FalseFalse
# grabbing page for...Edward Hicks
# Errors:FalseFalse
# grabbing page for...Charles C. Hofmann
# Errors:FalseFalse
# grabbing page for...Winslow Homer
# Errors:FalseFalse
# grabbing page for...Thomas Hovenden
# Errors:FalseFalse
# grabbing page for...William James Hubard
# Errors:FalseFalse
# grabbing page for...William Morris Hunt
# Errors:FalseFalse
# grabbing page for...Charles Cromwell Ingham
# Errors:FalseFalse
# grabbing page for...George Inness
# Errors:FalseFalse
# grabbing page for...John Wesley Jarvis
# Errors:FalseFalse
# grabbing page for...Eastman Johnson
# Errors:FalseFalse
# grabbing page for...Matthew Harris Jouett
# Errors:FalseFalse
# grabbing page for...Frederick Kemmelmeyer
# Errors:FalseFalse
# grabbing page for...John Frederick Kensett
# Errors:FalseFalse
# grabbing page for...George Cochran Lambdin
# Errors:FalseFalse
# grabbing page for...Fitz Henry Lane
# Errors:FalseFalse
# grabbing page for...Louis Lang
# Errors:FalseFalse
# grabbing page for...Thomas Le Clear
# Errors:FalseFalse
# grabbing page for...Emanuel Leutze
# Errors:FalseFalse
# grabbing page for...Wilton Lockwood
# Errors:FalseFalse
# grabbing page for...Henry Augustus Loop
# Errors:FalseFalse
# grabbing page for...John Mare
# Errors:FalseTrue
# grabbing page for...Homer Dodge Martin
# Errors:FalseFalse
# grabbing page for...Francis Blackwell Mayer
# Errors:FalseFalse
# grabbing page for...Jervis McEntee
# Errors:FalseFalse
# grabbing page for...Frank Millet
# Errors:FalseFalse
# grabbing page for...Edward Moran
# Errors:FalseFalse
# grabbing page for...Samuel F. B. Morse
# Errors:FalseFalse
# grabbing page for...Reuben Moulthrop
# Errors:FalseFalse
# grabbing page for...Shepard Alonzo Mount
# Errors:FalseFalse
# grabbing page for...William Sidney Mount
# Errors:FalseFalse
# grabbing page for...John Neagle
# Errors:FalseFalse
# grabbing page for...Robert Loftin Newman
# Errors:FalseFalse
# grabbing page for...Charles Willson Peale
# Errors:FalseFalse
# grabbing page for...James Peale
# Errors:FalseFalse
# grabbing page for...Raphaelle Peale
# Errors:FalseFalse
# grabbing page for...Rembrandt Peale
# Errors:FalseFalse
# grabbing page for...Charles Sprague Pearce
# Errors:FalseFalse
# grabbing page for...Enoch Wood Perry
# Errors:FalseFalse
# grabbing page for...John F. Peto
# Errors:FalseFalse
# grabbing page for...Ammi Phillips
# Errors:FalseFalse
# grabbing page for...William Lamb Picknell
# Errors:FalseFalse
# grabbing page for...Jean Pillement
# Errors:FalseFalse
# grabbing page for...Matthew Pratt
# Errors:FalseFalse
# grabbing page for...John Quidor
# Errors:FalseFalse
# grabbing page for...Henry Ward Ranger
# Errors:FalseFalse
# grabbing page for...John Rasmussen
# Errors:FalseFalse
# grabbing page for...Frederic Remington
# Errors:FalseFalse
# grabbing page for...William Trost Richards
# Errors:FalseFalse
# grabbing page for...Ferdinand Richardt
# Errors:FalseFalse
# grabbing page for...Theodore Robinson
# Errors:FalseFalse
# grabbing page for...Severin Roesen
# Errors:FalseFalse
# grabbing page for...Thomas Pritchard Rossiter
# Errors:FalseFalse
# grabbing page for...Robert Salmon
# Errors:FalseFalse
# grabbing page for...Charles Schreyvogel
# Errors:FalseFalse
# grabbing page for...Joshua Shaw
# Errors:FalseFalse
# grabbing page for...Walter Shirlaw
# Errors:FalseFalse
# grabbing page for...John Smibert
# Errors:FalseFalse
# grabbing page for...Joseph Steward
# Errors:FalseFalse
# grabbing page for...William Oliver Stone
# Errors:FalseFalse
# grabbing page for...Thomas Sully
# Errors:FalseFalse
# grabbing page for...Arthur Fitzwilliam Tait
# Errors:FalseFalse
# grabbing page for...Jeremiah Theus
# Errors:FalseFalse
# grabbing page for...Cephas Thompson
# Errors:FalseTrue
# grabbing page for...John Trumbull
# Errors:FalseFalse
# grabbing page for...John Henry Twachtman
# Errors:FalseFalse
# grabbing page for...John Mix Stanley
# Errors:FalseFalse
# grabbing page for...Pieter Vanderlyn
# Errors:FalseFalse
# grabbing page for...Godfrey Kneller
# Errors:FalseFalse
# grabbing page for...James McNeill Whistler
# Errors:FalseFalse
# grabbing page for...John Vanderlyn
# Errors:FalseFalse
# grabbing page for...Samuel Lovett Waldo
# Errors:FalseFalse
# grabbing page for...Charles Caleb Ward
# Errors:FalseFalse
# grabbing page for...Edgar Melville Ward
# Errors:FalseFalse
# grabbing page for...Edwin Lord Weeks
# Errors:FalseFalse
# grabbing page for...Robert Walter Weir
# Errors:FalseFalse
# grabbing page for...Benjamin West
# Errors:FalseFalse
# grabbing page for...Edwin White
# Errors:FalseFalse
# grabbing page for...Thomas Waterman Wood
# Errors:FalseFalse
# grabbing page for...Alexander H. Wyant
# Errors:FalseFalse
# grabbing page for...Lilly Martin Spencer
# Errors:FalseFalse
# grabbing page for...Carducius Plantagenet Ream
# Errors:FalseFalse
# grabbing page for...Angelica Kauffmann
# Errors:FalseFalse
# grabbing page for...Sōami
# Errors:FalseFalse
# grabbing page for...Giovanni da Udine
# Errors:FalseFalse
# grabbing page for...François Boucher
# Errors:FalseFalse
# grabbing page for...Willem van Leen
# Errors:FalseFalse
# grabbing page for...Antonio Zucchi
# Errors:FalseFalse
# grabbing page for...Joshua Reynolds
# Errors:FalseFalse
# grabbing page for...Jacopo Amigoni
# Errors:FalseFalse
# grabbing page for...Fra Angelico
# Errors:FalseFalse
# grabbing page for...Zanobi Strozzi
# Errors:FalseFalse
# grabbing page for...Antonello da Messina
# Errors:FalseFalse
# grabbing page for...Antoniazzo Romano
# Errors:FalseFalse
# grabbing page for...Jacques d' Arthois
# Errors:FalseFalse
# grabbing page for...David Bailly
# Errors:FalseFalse
# grabbing page for...Hans Baldung
# Errors:FalseFalse
# grabbing page for...Charles Bargue
# Errors:FalseFalse
# grabbing page for...Fra Bartolomeo
# Errors:FalseFalse
# grabbing page for...Bartolomeo degli Erri
# Errors:FalseFalse
# grabbing page for...Jules Bastien-Lepage
# Errors:FalseFalse
# grabbing page for...Pompeo Batoni
# Errors:FalseFalse
# grabbing page for...Jean-Frédéric Bazille
# Errors:FalseFalse
# grabbing page for...William Beechey
# Errors:FalseFalse
# grabbing page for...Giovanni Bellini
# Errors:FalseFalse
# grabbing page for...Jacopo Bellini
# Errors:FalseFalse
# grabbing page for...Bernardo Bellotto
# Errors:FalseFalse
# grabbing page for...Benjamin-Constant
# Errors:FalseFalse
# grabbing page for...Ambrosius Benson
# Errors:FalseFalse
# grabbing page for...Nicolaes Berchem
# Errors:FalseFalse
# grabbing page for...Bergognone
# Errors:FalseFalse
# grabbing page for...Berlinghiero
# Errors:FalseFalse
# grabbing page for...Abraham van Beyeren
# Errors:FalseFalse
# grabbing page for...Biagio d'Antonio
# Errors:FalseFalse
# grabbing page for...Cornelis Bisschop
# Errors:FalseFalse
# grabbing page for...William Blake
# Errors:FalseFalse
# grabbing page for...Jacques Blanchard
# Errors:FalseFalse
# grabbing page for...Herri met de Bles
# Errors:FalseFalse
# grabbing page for...Abraham Bloemaert
# Errors:FalseFalse
# grabbing page for...Boccaccio Boccaccino
# Errors:FalseFalse
# grabbing page for...Arnold Böcklin
# Errors:FalseFalse
# grabbing page for...Louis Léopold Boilly
# Errors:FalseFalse
# grabbing page for...Ferdinand Bol
# Errors:FalseFalse
# grabbing page for...Giovanni Boldini
# Errors:FalseFalse
# grabbing page for...Rosa Bonheur
# Errors:FalseFalse
# grabbing page for...Bonifacio de' Pitati
# Errors:FalseFalse
# grabbing page for...Richard Parkes Bonington
# Errors:FalseFalse
# grabbing page for...Anthonie van Borssom
# Errors:FalseFalse
# grabbing page for...Hieronymus Bosch
# Errors:FalseFalse
# grabbing page for...Giuseppe Bottani
# Errors:FalseFalse
# grabbing page for...Botticelli
# Errors:FalseFalse
# grabbing page for...Francesco Botticini
# Errors:FalseFalse
# grabbing page for...Eugène Boudin
# Errors:FalseFalse
# grabbing page for...William Bouguereau
# Errors:FalseFalse
# grabbing page for...Sébastien Bourdon
# Errors:FalseFalse
# grabbing page for...Aelbert Bouts
# Errors:FalseFalse
# grabbing page for...Dieric Bouts
# Errors:FalseFalse
# grabbing page for...Hans Traut
# Errors:FalseFalse
# grabbing page for...Bramantino
# Errors:FalseFalse
# grabbing page for...Leonaert Bramer
# Errors:FalseFalse
# grabbing page for...Bartholomeus Breenbergh
# Errors:FalseFalse
# grabbing page for...Quirijn van Brekelenkam
# Errors:FalseFalse
# grabbing page for...Jules Breton
# Errors:FalseFalse
# grabbing page for...Bronzino
# Errors:FalseFalse
# grabbing page for...Hans Brosamer
# Errors:FalseFalse
# grabbing page for...Adriaen Brouwer
# Errors:FalseFalse
# grabbing page for...Hendrick ter Brugghen
# Errors:FalseFalse
# grabbing page for...Barthel Bruyn
# Errors:FalseFalse
# grabbing page for...Edward Burne-Jones
# Errors:FalseFalse
# grabbing page for...Francesco Cairo
# Errors:FalseFalse
# grabbing page for...Bernardino Campi
# Errors:FalseFalse
# grabbing page for...Robert Campin
# Errors:FalseFalse
# grabbing page for...Canaletto
# Errors:FalseFalse
# grabbing page for...Jan van de Cappelle
# Errors:FalseFalse
# grabbing page for...Caravaggio
# Errors:FalseFalse
# grabbing page for...Fra Carnevale
# Errors:FalseFalse
# grabbing page for...Vittore Carpaccio
# Errors:FalseFalse
# grabbing page for...Eugène Carrière
# Errors:FalseFalse
# grabbing page for...Théodore Caruelle d' Aligny
# Errors:FalseFalse
# grabbing page for...Francesco Casanova
# Errors:FalseFalse
# grabbing page for...Bernardo Cavallino
# Errors:FalseFalse
# grabbing page for...Jean-Charles Cazin
# Errors:FalseFalse
# grabbing page for...Cenni di Francesco di Ser Cenni
# Errors:FalseFalse
# grabbing page for...Giacomo Ceruti
# Errors:FalseFalse
# grabbing page for...Paul Cézanne
# Errors:FalseFalse
# grabbing page for...Philippe de Champaigne
# Errors:FalseFalse
# grabbing page for...Jean Siméon Chardin
# Errors:FalseFalse
# grabbing page for...Giuseppe Bartolomeo Chiari
# Errors:FalseFalse
# grabbing page for...Petrus Christus
# Errors:FalseFalse
# grabbing page for...Cigoli
# Errors:FalseFalse
# grabbing page for...Cima da Conegliano
# Errors:FalseFalse
# grabbing page for...Pieter Claesz
# Errors:FalseFalse
# grabbing page for...Claude Lorrain
# Errors:FalseFalse
# grabbing page for...François Clouet
# Errors:FalseFalse
# grabbing page for...Jean Clouet
# Errors:FalseFalse
# grabbing page for...Marcellus Coffermans
# Errors:FalseFalse
# grabbing page for...Edwaert Collier
# Errors:FalseFalse
# grabbing page for...John Constable
# Errors:FalseFalse
# grabbing page for...Bernardino dei Conti
# Errors:FalseFalse
# grabbing page for...Corneille de Lyon
# Errors:FalseFalse
# grabbing page for...Camille Corot
# Errors:FalseFalse
# grabbing page for...Correggio
# Errors:FalseFalse
# grabbing page for...Richard Cosway
# Errors:FalseFalse
# grabbing page for...Francis Cotes
# Errors:FalseFalse
# grabbing page for...Gustave Courbet
# Errors:FalseFalse
# grabbing page for...Lucas Cranach
# Errors:FalseTrue
# grabbing page for...Gaspar de Crayer
# Errors:FalseFalse
# grabbing page for...Carlo Crivelli
# Errors:FalseFalse
# grabbing page for...Vittore Crivelli
# Errors:FalseFalse
# grabbing page for...John Crome
# Errors:FalseFalse
# grabbing page for...Abraham van Cuylenborch
# Errors:FalseFalse
# grabbing page for...Aelbert Cuyp
# Errors:FalseFalse
# grabbing page for...Bernardo Daddi
# Errors:FalseFalse
# grabbing page for...Michael Dahl
# Errors:FalseFalse
# grabbing page for...Cesare Dandini
# Errors:FalseFalse
# grabbing page for...Charles-François Daubigny
# Errors:FalseFalse
# grabbing page for...Honoré Daumier
# Errors:FalseFalse
# grabbing page for...Gerard David
# Errors:FalseFalse
# grabbing page for...Simon Bening
# Errors:FalseFalse
# grabbing page for...Jacques Louis David
# Errors:FalseFalse
# grabbing page for...Alexandre-Gabriel Decamps
# Errors:FalseFalse
# grabbing page for...Léonard Defrance
# Errors:FalseFalse
# grabbing page for...Edgar Degas
# Errors:FalseFalse
# grabbing page for...Eugène Delacroix
# Errors:FalseFalse
# grabbing page for...Édouard Detaille
# Errors:FalseFalse
# grabbing page for...Eugène Devéria
# Errors:FalseFalse
# grabbing page for...Narcisse-Virgile Diaz de la Peña
# Errors:FalseFalse
# grabbing page for...Abraham van Diepenbeeck
# Errors:FalseFalse
# grabbing page for...Christian Wilhelm Ernst Dietrich
# Errors:FalseFalse
# grabbing page for...Domenichino
# Errors:FalseFalse
# grabbing page for...Gustave Doré
# Errors:FalseFalse
# grabbing page for...Dosso Dossi
# Errors:FalseFalse
# grabbing page for...Gerrit Dou
# Errors:FalseFalse
# grabbing page for...Willem Drost
# Errors:FalseFalse
# grabbing page for...Jacob Duck
# Errors:FalseFalse
# grabbing page for...Gaspard Dughet
# Errors:FalseFalse
# grabbing page for...Pierre Louis Dumesnil
# Errors:FalseFalse
# grabbing page for...Joseph Siffred Duplessis
# Errors:FalseFalse
# grabbing page for...Gainsborough Dupont
# Errors:FalseFalse
# grabbing page for...Jules Dupré
# Errors:FalseFalse
# grabbing page for...Albrecht Dürer
# Errors:FalseFalse
# grabbing page for...Anthony van Dyck
# Errors:FalseFalse
# grabbing page for...Gerbrand van den Eeckhout
# Errors:FalseFalse
# grabbing page for...Charles Dominique Joseph Eisen
# Errors:FalseFalse
# grabbing page for...Cornelis Engebrechtsz
# Errors:FalseFalse
# grabbing page for...William Etty
# Errors:FalseFalse
# grabbing page for...Barent Fabritius
# Errors:FalseFalse
# grabbing page for...Henri Fantin-Latour
# Errors:FalseFalse
# grabbing page for...Defendente Ferrari
# Errors:FalseFalse
# grabbing page for...Domenico Fetti
# Errors:FalseFalse
# grabbing page for...Georg Flegel
# Errors:FalseFalse
# grabbing page for...Govert Flinck
# Errors:FalseFalse
# grabbing page for...Lavinia Fontana
# Errors:FalseFalse
# grabbing page for...Vincenzo Foppa
# Errors:FalseFalse
# grabbing page for...Jean Honoré Fragonard
# Errors:FalseFalse
# grabbing page for...Francesco di Giorgio Martini
# Errors:FalseFalse
# grabbing page for...Francesco Francia
# Errors:FalseFalse
# grabbing page for...Antoine Rivalz
# Errors:FalseFalse
# grabbing page for...Charles-Théodore Frère
# Errors:FalseFalse
# grabbing page for...Eugène Fromentin
# Errors:FalseFalse
# grabbing page for...Bernardino Fungai
# Errors:FalseFalse
# grabbing page for...Henry Fuseli
# Errors:FalseFalse
# grabbing page for...Jan Fyt
# Errors:FalseFalse
# grabbing page for...Agnolo Gaddi
# Errors:FalseFalse
# grabbing page for...Thomas Gainsborough
# Errors:FalseFalse
# grabbing page for...Saturnino Gatti
# Errors:FalseFalse
# grabbing page for...Paul Gauguin
# Errors:FalseFalse
# grabbing page for...Gentile da Fabriano
# Errors:FalseFalse
# grabbing page for...Artemisia Gentileschi
# Errors:FalseFalse
# grabbing page for...Théodore Gericault
# Errors:FalseFalse
# grabbing page for...Niccolò di Pietro Gerini
# Errors:FalseFalse
# grabbing page for...Jean-Léon Gérôme
# Errors:FalseFalse
# grabbing page for...Domenico Ghirlandaio
# Errors:FalseFalse
# grabbing page for...Davide Ghirlandaio
# Errors:FalseFalse
# grabbing page for...Michele Giambono
# Errors:FalseFalse
# grabbing page for...Giampietrino
# Errors:FalseFalse
# grabbing page for...Luca Giordano
# Errors:FalseFalse
# grabbing page for...Giotto di Bondone
# Errors:FalseFalse
# grabbing page for...Giovanni di Paolo
# Errors:FalseFalse
# grabbing page for...Pierre Gobert
# Errors:FalseFalse
# grabbing page for...Hugo van der Goes
# Errors:FalseFalse
# grabbing page for...Vincent van Gogh
# Errors:FalseFalse
# grabbing page for...Jan Gossart
# Errors:FalseFalse
# grabbing page for...Goya
# Errors:FalseFalse
# grabbing page for...Jan van Goyen
# Errors:FalseFalse
# grabbing page for...Benozzo Gozzoli
# Errors:FalseFalse
# grabbing page for...Francesco Granacci
# Errors:FalseFalse
# grabbing page for...François Marius Granet
# Errors:FalseFalse
# grabbing page for...El Greco
# Errors:FalseFalse
# grabbing page for...Jean-Baptiste Greuze
# Errors:FalseFalse
# grabbing page for...Francesco Guardi
# Errors:FalseFalse
# grabbing page for...Guariento di Arpo
# Errors:FalseFalse
# grabbing page for...Guercino
# Errors:FalseFalse
# grabbing page for...Domenico Guidobono
# Errors:FalseFalse
# grabbing page for...Dirck Hals
# Errors:FalseFalse
# grabbing page for...Frans Hals
# Errors:FalseFalse
# grabbing page for...Adriaen Hanneman
# Errors:FalseFalse
# grabbing page for...George Henry Harlow
# Errors:FalseFalse
# grabbing page for...Henri-Joseph Harpignies
# Errors:FalseFalse
# grabbing page for...Margareta Haverman
# Errors:FalseFalse
# grabbing page for...Jan Davidsz de Heem
# Errors:FalseFalse
# grabbing page for...Maarten van Heemskerck
# Errors:FalseFalse
# grabbing page for...Bartholomeus van der Helst
# Errors:FalseFalse
# grabbing page for...Jan Sanders van Hemessen
# Errors:FalseFalse
# grabbing page for...Jean-Jacques Henner
# Errors:FalseFalse
# grabbing page for...Jan van der Heyden
# Errors:FalseFalse
# grabbing page for...Meyndert Hobbema
# Errors:FalseFalse
# grabbing page for...William Hogarth
# Errors:FalseFalse
# grabbing page for...Melchior d' Hondecoeter
# Errors:FalseFalse
# grabbing page for...Abraham Hondius
# Errors:FalseFalse
# grabbing page for...Pieter de Hooch
# Errors:FalseFalse
# grabbing page for...Samuel van Hoogstraten
# Errors:FalseFalse
# grabbing page for...John Hoppner
# Errors:FalseFalse
# grabbing page for...Peter Jacob Horemans
# Errors:FalseFalse
# grabbing page for...Jacob van Hulsdonck
# Errors:FalseFalse
# grabbing page for...Pieter Huys
# Errors:FalseFalse
# grabbing page for...Jean Auguste Dominique Ingres
# Errors:FalseFalse
# grabbing page for...Adriaen Isenbrant
# Errors:FalseFalse
# grabbing page for...Jozef Israëls
# Errors:FalseFalse
# grabbing page for...Abraham Brueghel
# Errors:FalseFalse
# grabbing page for...Jacometto
# Errors:FalseFalse
# grabbing page for...Jacopino del Conte
# Errors:FalseFalse
# grabbing page for...Daniele da Volterra
# Errors:FalseFalse
# grabbing page for...Charles Jacque
# Errors:FalseFalse
# grabbing page for...Antonio Joli
# Errors:FalseFalse
# grabbing page for...Ludolf de Jongh
# Errors:FalseFalse
# grabbing page for...Johan Barthold Jongkind
# Errors:FalseFalse
# grabbing page for...Cornelis Jonson van Ceulen
# Errors:FalseFalse
# grabbing page for...Joos van Cleve
# Errors:FalseFalse
# grabbing page for...Jacob Jordaens
# Errors:FalseFalse
# grabbing page for...Juan de Flandes
# Errors:FalseFalse
# grabbing page for...Justus of Ghent
# Errors:FalseFalse
# grabbing page for...Wilhelm von Kaulbach
# Errors:FalseFalse
# grabbing page for...Bernhard Keil
# Errors:FalseFalse
# grabbing page for...Kerstiaen de Keuninck
# Errors:FalseFalse
# grabbing page for...Thomas de Keyser
# Errors:FalseFalse
# grabbing page for...Gustav Klimt
# Errors:FalseFalse
# grabbing page for...Thomas Frye
# Errors:FalseFalse
# grabbing page for...Christen Købke
# Errors:FalseFalse
# grabbing page for...Barend Cornelis Koekkoek
# Errors:FalseFalse
# grabbing page for...Philips Koninck
# Errors:FalseFalse
# grabbing page for...Arkhip Ivanovich Kuindzhi
# Errors:FalseFalse
# grabbing page for...Hans Süss von Kulmbach
# Errors:FalseFalse
# grabbing page for...Laurent de La Hyre
# Errors:FalseFalse
# grabbing page for...Georges de La Tour
# Errors:FalseFalse
# grabbing page for...Adélaïde Labille-Guiard
# Errors:FalseFalse
# grabbing page for...Gerard de Lairesse
# Errors:FalseFalse
# grabbing page for...Edwin Henry Landseer
# Errors:FalseFalse
# grabbing page for...Eugène Lavieille
# Errors:FalseFalse
# grabbing page for...Thomas Lawrence
# Errors:FalseFalse
# grabbing page for...Eustache Le Sueur
# Errors:FalseFalse
# grabbing page for...Frederick Richard Lee
# Errors:FalseFalse
# grabbing page for...Jules-Joseph Lefebvre
# Errors:FalseFalse
# grabbing page for...Wilhelm Leibl
# Errors:FalseFalse
# grabbing page for...Frederic Leighton
# Errors:FalseFalse
# grabbing page for...Alexandre-Louis Leloir
# Errors:FalseFalse
# grabbing page for...Peter Lely
# Errors:FalseFalse
# grabbing page for...Marie Victoire Lemoine
# Errors:FalseFalse
# grabbing page for...Franz von Lenbach
# Errors:FalseFalse
# grabbing page for...Henry Lerolle
# Errors:FalseFalse
# grabbing page for...Jacopo Ligozzi
# Errors:FalseFalse
# grabbing page for...Johannes Lingelbach
# Errors:FalseFalse
# grabbing page for...Andrea di Lione
# Errors:FalseFalse
# grabbing page for...Filippino Lippi
# Errors:FalseFalse
# grabbing page for...Fra Filippo Lippi
# Errors:FalseFalse
# grabbing page for...Pietro Longhi
# Errors:FalseFalse
# grabbing page for...Ambrogio Lorenzetti
# Errors:FalseFalse
# grabbing page for...Pietro Lorenzetti
# Errors:FalseFalse
# grabbing page for...Lorenzo di Credi
# Errors:FalseFalse
# grabbing page for...Lorenzo Monaco
# Errors:FalseFalse
# grabbing page for...Lorenzo Lotto
# Errors:FalseFalse
# grabbing page for...Lucas van Leyden
# Errors:FalseFalse
# grabbing page for...Raimundo de Madrazo y Garreta
# Errors:FalseFalse
# grabbing page for...Nicolaes Maes
# Errors:FalseFalse
# grabbing page for...Alessandro Magnasco
# Errors:FalseFalse
# grabbing page for...Hans Makart
# Errors:FalseFalse
# grabbing page for...Hans Maler
# Errors:FalseFalse
# grabbing page for...Édouard Manet
# Errors:FalseFalse
# grabbing page for...Andrea Mantegna
# Errors:FalseFalse
# grabbing page for...Émile van Marcke
# Errors:FalseFalse
# grabbing page for...Jacob Maris
# Errors:FalseFalse
# grabbing page for...Otto Marseus van Schrieck
# Errors:FalseFalse
# grabbing page for...Maso di Banco
# Errors:FalseFalse
# grabbing page for...Quentin Metsys
# Errors:FalseFalse
# grabbing page for...Master of the Castello Nativity
# Errors:FalseFalse
# grabbing page for...Master of Flora
# Errors:FalseFalse
# grabbing page for...Netherlandish
# Errors:FalseFalse
# grabbing page for...Master of the Mansi Magdalen
# Errors:FalseFalse
# grabbing page for...Master of Varlungo
# Errors:FalseFalse
# grabbing page for...Master of the View of Sainte Gudule
# Errors:FalseFalse
# grabbing page for...Anton Mauve
# Errors:FalseFalse
# grabbing page for...Gabriel Max
# Errors:FalseFalse
# grabbing page for...Juan Bautista Martínez del Mazo
# Errors:FalseFalse
# grabbing page for...Ernest Meissonier
# Errors:FalseFalse
# grabbing page for...Hans Memling
# Errors:FalseFalse
# grabbing page for...Lippo Memmi
# Errors:FalseFalse
# grabbing page for...Anton Raphael Mengs
# Errors:FalseFalse
# grabbing page for...Hugues Merle
# Errors:FalseFalse
# grabbing page for...Gabriël Metsu
# Errors:FalseFalse
# grabbing page for...Adam Frans van der Meulen
# Errors:FalseFalse
# grabbing page for...Achille-Etna Michallon
# Errors:FalseFalse
# grabbing page for...Michele da Verona
# Errors:FalseFalse
# grabbing page for...Michelino da Besozzo
# Errors:FalseFalse
# grabbing page for...Jan Miel
# Errors:FalseFalse
# grabbing page for...Michiel Jansz. van Mierevelt
# Errors:FalseFalse
# grabbing page for...Arnold Boonen
# Errors:FalseFalse
# grabbing page for...Daniël Mijtens
# Errors:FalseFalse
# grabbing page for...John Everett Millais
# Errors:FalseFalse
# grabbing page for...Francisque Millet
# Errors:FalseFalse
# grabbing page for...Jean-François Millet
# Errors:FalseFalse
# grabbing page for...Pier Francesco Mola
# Errors:FalseFalse
# grabbing page for...Pieter de Molijn
# Errors:FalseFalse
# grabbing page for...Peter Monamy
# Errors:FalseFalse
# grabbing page for...Bartolomeo Montagna
# Errors:FalseFalse
# grabbing page for...Francesco Montemezzano
# Errors:FalseFalse
# grabbing page for...Adolphe Monticelli
# Errors:FalseFalse
# grabbing page for...Anthonis Mor van Dashorst
# Errors:FalseFalse
# grabbing page for...Paulus Moreelse
# Errors:FalseFalse
# grabbing page for...Moretto da Brescia
# Errors:FalseFalse
# grabbing page for...Berthe Morisot
# Errors:FalseFalse
# grabbing page for...George Morland
# Errors:FalseFalse
# grabbing page for...Giovanni Battista Moroni
# Errors:FalseFalse
# grabbing page for...Jan Mostaert
# Errors:FalseFalse
# grabbing page for...Mihály Munkácsy
# Errors:FalseFalse
# grabbing page for...Emanuel Murant
# Errors:FalseFalse
# grabbing page for...Martin van Meytens
# Errors:FalseFalse
# grabbing page for...Matthijs Naiveu
# Errors:FalseFalse
# grabbing page for...Patrick Nasmyth
# Errors:FalseFalse
# grabbing page for...Charles Joseph Natoire
# Errors:FalseFalse
# grabbing page for...Jean Marc Nattier
# Errors:FalseFalse
# grabbing page for...Aert van der Neer
# Errors:FalseFalse
# grabbing page for...Eglon van der Neer
# Errors:FalseFalse
# grabbing page for...Neroccio de' Landi
# Errors:FalseFalse
# grabbing page for...Master of the Female Half-Lengths
# Errors:FalseFalse
# grabbing page for...Caspar Netscher
# Errors:FalseFalse
# grabbing page for...Alphonse-Marie-Adolphe de Neuville
# Errors:FalseFalse
# grabbing page for...Niccolò di Buonaccorso
# Errors:FalseFalse
# grabbing page for...Niccolò di Pietro
# Errors:FalseFalse
# grabbing page for...Jacob Ochtervelt
# Errors:FalseFalse
# grabbing page for...Bernard van Orley
# Errors:FalseFalse
# grabbing page for...Adriaen van Ostade
# Errors:FalseFalse
# grabbing page for...Jean-Baptiste Oudry
# Errors:FalseFalse
# grabbing page for...Jürgen Ovens
# Errors:FalseFalse
# grabbing page for...Benedetto Pagni
# Errors:FalseFalse
# grabbing page for...Jacopo Palma
# Errors:FalseFalse
# grabbing page for...Guido Palmeruccio
# Errors:FalseFalse
# grabbing page for...Giovanni Paolo Panini
# Errors:FalseFalse
# grabbing page for...Paolo di Giovanni Fei
# Errors:FalseFalse
# grabbing page for...Paolo Veneziano
# Errors:FalseFalse
# grabbing page for...Girolamo Mazzola Bedoli
# Errors:FalseFalse
# grabbing page for...Alberto Pasini
# Errors:FalseFalse
# grabbing page for...Mirabello Cavalori
# Errors:FalseFalse
# grabbing page for...Laurent Pécheux
# Errors:FalseFalse
# grabbing page for...Giovanni Antonio Pellegrini
# Errors:FalseFalse
# grabbing page for...Perugino
# Errors:FalseFalse
# grabbing page for...Baldassare Tommaso Peruzzi
# Errors:FalseFalse
# grabbing page for...Pesellino
# Errors:FalseFalse
# grabbing page for...Giovanni Battista Piazzetta
# Errors:FalseFalse
# grabbing page for...Nicolaes Eliasz Pickenoy
# Errors:FalseFalse
# grabbing page for...Piero di Cosimo
# Errors:FalseFalse
# grabbing page for...Jean-Baptiste Marie Pierre
# Errors:FalseFalse
# grabbing page for...Pietro di Domenico da Montepulciano
# Errors:FalseTrue
# grabbing page for...Pietro di Francesco Orioli
# Errors:FalseFalse
# grabbing page for...Karl Theodor von Piloty
# Errors:FalseFalse
# grabbing page for...Alvaro Pirez
# Errors:FalseFalse
# grabbing page for...Camille Pissarro
# Errors:FalseFalse
# grabbing page for...Frans Post
# Errors:FalseFalse
# grabbing page for...Pieter Jansz. Pourbus
# Errors:FalseFalse
# grabbing page for...Nicolas Poussin
# Errors:FalseFalse
# grabbing page for...Giovanni Ambrogio de Predis
# Errors:FalseFalse
# grabbing page for...Mattia Preti
# Errors:FalseFalse
# grabbing page for...Giulio Cesare Procaccini
# Errors:FalseFalse
# grabbing page for...Jan Provost
# Errors:FalseFalse
# grabbing page for...Pierre Paul Prud'hon
# Errors:FalseFalse
# grabbing page for...Scipione Pulzone
# Errors:FalseFalse
# grabbing page for...Pierre Puvis de Chavannes
# Errors:FalseFalse
# grabbing page for...Jacob Pynas
# Errors:FalseFalse
# grabbing page for...Henry Raeburn
# Errors:FalseFalse
# grabbing page for...Raffaellino del Garbo
# Errors:FalseFalse
# grabbing page for...Raphael
# Errors:FalseFalse
# grabbing page for...Jan van Ravesteyn
# Errors:FalseFalse
# grabbing page for...Giuseppe Recco
# Errors:FalseFalse
# grabbing page for...Odilon Redon
# Errors:FalseFalse
# grabbing page for...Henri Regnault
# Errors:FalseFalse
# grabbing page for...Rembrandt
# Errors:FalseFalse
# grabbing page for...Guido Reni
# Errors:FalseFalse
# grabbing page for...Auguste Renoir
# Errors:FalseFalse
# grabbing page for...Jusepe de Ribera
# Errors:FalseFalse
# grabbing page for...Sebastiano Ricci
# Errors:FalseFalse
# grabbing page for...Hyacinthe Rigaud
# Errors:FalseFalse
# grabbing page for...Hubert Robert
# Errors:FalseFalse
# grabbing page for...Rogier van der Weyden
# Errors:FalseFalse
# grabbing page for...Giovanni Francesco Romanelli
# Errors:FalseFalse
# grabbing page for...John Westbrooke Chandler
# Errors:FalseFalse
# grabbing page for...Salvator Rosa
# Errors:FalseFalse
# grabbing page for...Cosimo Rosselli
# Errors:FalseFalse
# grabbing page for...Henri Rousseau
# Errors:FalseFalse
# grabbing page for...Philippe Rousseau
# Errors:FalseFalse
# grabbing page for...Théodore Rousseau
# Errors:FalseFalse
# grabbing page for...Peter Paul Rubens
# Errors:FalseFalse
# grabbing page for...Jacob van Ruisdael
# Errors:FalseFalse
# grabbing page for...Salomon van Ruysdael
# Errors:FalseFalse
# grabbing page for...Andrea Sacchi
# Errors:FalseFalse
# grabbing page for...Carlo Saraceni
# Errors:FalseFalse
# grabbing page for...Andrea del Sarto
# Errors:FalseFalse
# grabbing page for...Sassetta
# Errors:FalseFalse
# grabbing page for...Giovanni Gerolamo Savoldo
# Errors:FalseFalse
# grabbing page for...Godfried Schalcken
# Errors:FalseFalse
# grabbing page for...Andrea Schiavone
# Errors:FalseFalse
# grabbing page for...Ludwig Schongauer
# Errors:FalseFalse
# grabbing page for...Julius Schrader
# Errors:FalseFalse
# grabbing page for...Adolf Schreyer
# Errors:FalseFalse
# grabbing page for...Sebastiano del Piombo
# Errors:FalseFalse
# grabbing page for...Enoch Seeman
# Errors:FalseFalse
# grabbing page for...Segna di Buonaventura
# Errors:FalseFalse
# grabbing page for...Jacopo del Sellaio
# Errors:FalseFalse
# grabbing page for...Georges Seurat
# Errors:FalseFalse
# grabbing page for...James Seymour
# Errors:FalseFalse
# grabbing page for...Martin Archer Shee
# Errors:FalseFalse
# grabbing page for...Luca Signorelli
# Errors:FalseFalse
# grabbing page for...Simone Martini
# Errors:FalseFalse
# grabbing page for...Alfred Sisley
# Errors:FalseFalse
# grabbing page for...Pieter Snayers
# Errors:FalseFalse
# grabbing page for...Andrea Solario
# Errors:FalseFalse
# grabbing page for...Hendrick Sorgh
# Errors:FalseFalse
# grabbing page for...Ignacio de Ries
# Errors:FalseFalse
# grabbing page for...Massimo Stanzione
# Errors:FalseFalse
# grabbing page for...Matthias Stom
# Errors:FalseFalse
# grabbing page for...Bernhard Strigel
# Errors:FalseFalse
# grabbing page for...Jacob van Strij
# Errors:FalseFalse
# grabbing page for...Bernardo Strozzi
# Errors:FalseFalse
# grabbing page for...George Stubbs
# Errors:FalseFalse
# grabbing page for...Justus Sustermans
# Errors:FalseFalse
# grabbing page for...Lambert Sustris
# Errors:FalseFalse
# grabbing page for...Michiel Sweerts
# Errors:FalseFalse
# grabbing page for...Nicolas Antoine Taunay
# Errors:FalseFalse
# grabbing page for...Pietro Testa
# Errors:FalseFalse
# grabbing page for...Giovanni Battista Tiepolo
# Errors:FalseFalse
# grabbing page for...Giovanni Domenico Tiepolo
# Errors:FalseFalse
# grabbing page for...Gillis van Tilborgh
# Errors:FalseFalse
# grabbing page for...Jacopo Tintoretto
# Errors:FalseFalse
# grabbing page for...Titian
# Errors:FalseFalse
# grabbing page for...Henri de Toulouse-Lautrec
# Errors:FalseFalse
# grabbing page for...Gaspare Traversi
# Errors:FalseFalse
# grabbing page for...Constant Troyon
# Errors:FalseFalse
# grabbing page for...Wilhelm Trübner
# Errors:FalseFalse
# grabbing page for...Cosmè Tura
# Errors:FalseFalse
# grabbing page for...Joseph Mallord William Turner
# Errors:FalseFalse
# grabbing page for...Fritz von Uhde
# Errors:FalseFalse
# grabbing page for...Wallerant Vaillant
# Errors:FalseFalse
# grabbing page for...Juan de Valdés Leal
# Errors:FalseFalse
# grabbing page for...Anne Vallayer-Coster
# Errors:FalseFalse
# grabbing page for...Carle Vanloo
# Errors:FalseFalse
# grabbing page for...Lippo Vanni
# Errors:FalseFalse
# grabbing page for...Velázquez
# Errors:FalseFalse
# grabbing page for...Willem van de Velde
# Errors:FalseFalse
# grabbing page for...Johannes Vermeer
# Errors:FalseFalse
# grabbing page for...Joseph Vernet
# Errors:FalseFalse
# grabbing page for...Horace Vernet
# Errors:FalseFalse
# grabbing page for...Paolo Veronese
# Errors:FalseFalse
# grabbing page for...Andrea del Verrocchio
# Errors:FalseFalse
# grabbing page for...Johannes Verspronck
# Errors:FalseFalse
# grabbing page for...Antoine Vestier
# Errors:FalseFalse
# grabbing page for...Jean-Georges Vibert
# Errors:FalseFalse
# grabbing page for...Jan Victors
# Errors:FalseFalse
# grabbing page for...Élisabeth Louise Vigée Le Brun
# Errors:FalseFalse
# grabbing page for...Antonio Vivarini
# Errors:FalseFalse
# grabbing page for...Bartolomeo Vivarini
# Errors:FalseFalse
# grabbing page for...Simon de Vlieger
# Errors:FalseFalse
# grabbing page for...Hendrick van Vliet
# Errors:FalseFalse
# grabbing page for...Antoine Vollon
# Errors:FalseFalse
# grabbing page for...Cornelis de Vos
# Errors:FalseFalse
# grabbing page for...Jacob Vosmaer
# Errors:FalseFalse
# grabbing page for...Roelof van Vries
# Errors:FalseFalse
# grabbing page for...Alfred Wahlberg
# Errors:FalseFalse
# grabbing page for...Antoine Watteau
# Errors:FalseFalse
# grabbing page for...Frederick Waters Watts
# Errors:FalseFalse
# grabbing page for...George Frederic Watts
# Errors:FalseFalse
# grabbing page for...Jan Weenix
# Errors:FalseFalse
# grabbing page for...Franz Xaver Winterhalter
# Errors:FalseFalse
# grabbing page for...Willem Wissing
# Errors:FalseFalse
# grabbing page for...Philips Wouwerman
# Errors:FalseFalse
# grabbing page for...Joachim Wtewael
# Errors:FalseFalse
# grabbing page for...Peter Wtewael
# Errors:FalseFalse
# grabbing page for...Francesco Zaganelli
# Errors:FalseFalse
# grabbing page for...Francesco Zuccarelli
# Errors:FalseFalse
# grabbing page for...Francisco de Zurbarán
# Errors:FalseFalse
# grabbing page for...Théodore Chassériau
# Errors:FalseFalse
# grabbing page for...Andreas Achenbach
# Errors:FalseFalse
# grabbing page for...Marcantonio Franceschini
# Errors:FalseFalse
# grabbing page for...Sodoma
# Errors:FalseFalse
# grabbing page for...Ivan Konstantinovich Aivazovsky
# Errors:FalseFalse
# grabbing page for...Taddeo Gaddi
# Errors:FalseFalse
# grabbing page for...Anne Louis Girodet-Trioson
# Errors:FalseFalse
# grabbing page for...James Tissot
# Errors:FalseFalse
# grabbing page for...Jean François de Troy
# Errors:FalseFalse
# grabbing page for...Santi di Tito
# Errors:FalseFalse
# grabbing page for...Christoffel van den Berghe
# Errors:FalseFalse
# grabbing page for...Willem Claesz Heda
# Errors:FalseFalse
# grabbing page for...Scarsellino
# Errors:FalseFalse
# grabbing page for...Johann Liss
# Errors:FalseFalse
# grabbing page for...Caspar David Friedrich
# Errors:FalseFalse
# grabbing page for...Ludovico Carracci
# Errors:FalseFalse
# grabbing page for...Emanuel de Witte
# Errors:FalseFalse
# grabbing page for...Edmond-François Aman-Jean
# Errors:FalseFalse
# grabbing page for...Sebastian Stoskopff
# Errors:FalseFalse
# grabbing page for...François Gérard
# Errors:FalseFalse
# grabbing page for...François Joseph Heim
# Errors:FalseFalse
# grabbing page for...Antoine Jean Gros
# Errors:FalseFalse
# grabbing page for...Johann Heinrich Wilhelm Tischbein
# Errors:FalseFalse
# grabbing page for...Adrien Dauzats
# Errors:FalseFalse
# grabbing page for...Simon Denis
# Errors:FalseFalse
# grabbing page for...Barna da Siena
# Errors:FalseFalse
# grabbing page for...Bartolo di Fredi
# Errors:FalseFalse
# grabbing page for...Osservanza Master
# Errors:FalseFalse
# grabbing page for...Benvenuto di Giovanni
# Errors:FalseFalse
# grabbing page for...Spinello Aretino
# Errors:FalseFalse
# grabbing page for...Andrea di Cione
# Errors:FalseFalse
# grabbing page for...Bicci di Lorenzo
# Errors:FalseFalse
# grabbing page for...Alesso di Benozzo
# Errors:FalseFalse
# grabbing page for...Lorenzo Veneziano
# Errors:FalseFalse
# grabbing page for...Luca Carlevaris
# Errors:FalseFalse
# grabbing page for...Giambattista Cimaroli
# Errors:FalseFalse
# grabbing page for...Antonio del Massaro da Viterbo
# Errors:FalseFalse
# grabbing page for...Giovanni Baronzio
# Errors:FalseFalse
# grabbing page for...Master of Saint Francis
# Errors:FalseFalse
# grabbing page for...Puccio di Simone
# Errors:FalseFalse
# grabbing page for...Niccolò Alunno
# Errors:FalseFalse
# grabbing page for...Master of Frankfurt
# Errors:FalseFalse
# grabbing page for...Simon Marmion
# Errors:FalseFalse
# grabbing page for...Jean Hey
# Errors:FalseFalse
# grabbing page for...Master of Saint Giles
# Errors:FalseFalse
# grabbing page for...Diego Rodríguez de Silva y Velázquez
# Errors:FalseFalse
# grabbing page for...Henri-Edmond Cross
# Errors:FalseFalse
# grabbing page for...Bartolomeo Bulgarini
# Errors:FalseFalse
# grabbing page for...first quarter of 14th century Italian [Tuscan] Painter
# Errors:FalseTrue
# grabbing page for...Domingo Ram
# Errors:FalseTrue
# grabbing page for...Master of the Codex of Saint George
# Errors:FalseFalse
# grabbing page for...Niccolò di Tommaso
# Errors:FalseTrue
# grabbing page for...Umberto Boccioni
# Errors:FalseFalse
# grabbing page for...William Tasker
# Errors:FalseFalse
# grabbing page for...Guillaume Voiriot
# Errors:FalseFalse
# grabbing page for...Juan Rodríguez Juárez
# Errors:FalseFalse
# grabbing page for...Nicolás Enríquez
# Errors:FalseFalse
# grabbing page for...William A. Harper
# Errors:FalseTrue
# Finished!

# %%
#now join back into the wip table; drop the original "Image" column (we'll use Image_link moving forward)
#Fill in all missing values with our anonymous_artist.png. 

artists_wip = artists_wip.join(artists_for_scrape, how = "left", on='Artist_id', rsuffix="_y")

# %%
artists_wip = artists_wip.drop(columns=["image", "Surname_y", "First_name_y", "Full_name_y", "Birth_date_y", "Death_date_y", "image_y", "Biography_y", "Artist_id_y"])

# %%
artists_wip = artists_wip.fillna("../static/img/anonymous_artist.png")
artists_wip.head(10)
# Out:
#       Surname            First_name                       Full_name  \
# 0   Defeuille  Louis Benjamin Huber  Louis Benjamin Huber Defeuille
# 2     Unknown                blank_                         Unknown
# 4        Nini         Jean-Baptiste              Jean-Baptiste Nini
# 5     Sanford                    H.                      H. Sanford
# 6     Babcock            William P.              William P. Babcock
# 7      Stuart               Gilbert                  Gilbert Stuart
# 9       Inman                 Henry                     Henry Inman
# 10   La Farge                  John                   John La Farge
# 11      Ryder        Albert Pinkham            Albert Pinkham Ryder
# 12      Abbey          Edwin Austin              Edwin Austin Abbey
#
#     Birth_date     Death_date  Artist_id  \
# 0      Unknown  Unknown                0
# 2      Unknown        Unknown          2
# 4   1717           1786                3
# 5   1783           1822                4
# 6   1826           1899                5
# 7   1755           1828                6
# 9   1801           1846                8
# 10  1835           1910                9
# 11  1847           1917               10
# 12  1852           1911               11
#
#                                             Biography  \
# 0                        Biography could not be found
# 2                        Biography could not be found
# 4                        Biography could not be found
# 5                        Biography could not be found
# 6                        Biography could not be found
# 7   s foremost portraitists.[2] His best known wor...
# 9                        Biography could not be found
# 10  John La Farge (March 31, 1835 – November 14, 1...
# 11  Albert Pinkham Ryder (March 19, 1847 – March 2...
# 12  Edwin Austin Abbey RA (April 1, 1852\xa0– Augu...
#
#                                            Image_link
# 0                  ../static/img/anonymous_artist.png
# 2                  ../static/img/anonymous_artist.png
# 4                  ../static/img/anonymous_artist.png
# 5                  ../static/img/anonymous_artist.png
# 6                  ../static/img/anonymous_artist.png
# 7                  ../static/img/anonymous_artist.png
# 9                  ../static/img/anonymous_artist.png
# 10                 ../static/img/anonymous_artist.png
# 11  //upload.wikimedia.org/wikipedia/commons/thumb...
# 12  //upload.wikimedia.org/wikipedia/commons/thumb...

# %%
#Finally, we need to double-check Biography to clean up some of the strings. Print out a few tests for records we know have bios
print(artists_wip.loc[10,'Biography'])
print("----")
print(artists_wip.loc[11,'Biography'])
print("----")
print(artists_wip.loc[12,'Biography'])
# Out:
# John La Farge (March 31, 1835 – November 14, 1910) was an American painter, muralist, stained glass window maker, decorator, and writer.\n
# ----
# Albert Pinkham Ryder (March 19, 1847 – March 28, 1917) was an American painter best known for his poetic and moody allegorical works and seascapes, as well as his eccentric personality. While his art shared an emphasis on subtle variations of color with tonalist works of the time, it was unique for accentuating form in a way that some art historians regard as modernist.\n
# ----
# Edwin Austin Abbey RA (April 1, 1852\xa0– August 1, 1911) was an American muralist, illustrator, and painter. He flourished at the beginning of what is now referred to as the "golden age" of illustration, and is best known for his drawings and paintings of Shakespearean and Victorian subjects, as well as for his painting of Edward VII\'s coronation.[1][2][3] His most famous set of murals, The Quest and Achievement of the Holy Grail, adorns the Boston Public Library.\n

# %%
#These Bios have a trailing "\n" as well a citation references "[x]" that we want to strip out

for index, row in artists_wip.iterrows():
    Biography = artists_wip.loc[index, "Biography"]
    
    if Biography != "Biography could not be found":
        Biography = Biography.replace(r"\n", "")
        Biography = Biography.replace("\\", "")
        Biography = re.sub("[\(\[].*?[\)\]]", "", Biography)
        Biography = Biography.replace(r'"]', "")
        
        artists_wip.loc[index, "Biography"] = Biography

# %%
#Tests are clean now!
print(artists_wip.loc[10,'Biography'])
print("----")
print(artists_wip.loc[11,'Biography'])
print("----")
print(artists_wip.loc[12,'Biography'])
# Out:
# John La Farge  was an American painter, muralist, stained glass window maker, decorator, and writer.
# ----
# Albert Pinkham Ryder  was an American painter best known for his poetic and moody allegorical works and seascapes, as well as his eccentric personality. While his art shared an emphasis on subtle variations of color with tonalist works of the time, it was unique for accentuating form in a way that some art historians regard as modernist.
# ----
# Edwin Austin Abbey RA  was an American muralist, illustrator, and painter. He flourished at the beginning of what is now referred to as the "golden age" of illustration, and is best known for his drawings and paintings of Shakespearean and Victorian subjects, as well as for his painting of Edward VII's coronation. His most famous set of murals, The Quest and Achievement of the Holy Grail, adorns the Boston Public Library.

# %%
#Save out the finalized paintings and artists files to csv
artists_wip.to_csv('')
