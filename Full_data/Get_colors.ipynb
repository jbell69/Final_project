# %%
#dependancies

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
from skimage.color import rgb2lab, deltaE_cie76
import os
import urllib
import webcolors

# %%
def get_image(image_path):

    resp = urllib.request.urlopen(image_path)
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image_modify = cv2.resize(image, (400,400), interpolation = cv2.INTER_AREA)
    image_final = image_modify.reshape(image_modify.shape[0]*image_modify.shape[1], 3)
    return image_final


def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

def closest_color(requested_color):
    min_colors = {}
    for key, name in webcolors.css3_hex_to_names.items():
        r_c, g_c, b_c = webcolors.hex_to_rgb(key)
        rd = (r_c - requested_color[0]) ** 2
        gd = (g_c - requested_color[1]) ** 2
        bd = (b_c - requested_color[2]) ** 2
        min_colors[(rd + gd + bd)] = name
    return min_colors[min(min_colors.keys())]

def get_color_name(requested_color):
    try:
        closest_name = actual_name = webcolors.rgb_to_name(requested_color)
    except ValueError:
        closest_name = closest_color(requested_color)
        actual_name = None
    return closest_name

def get_colors(image, number):
    clf = KMeans(n_clusters = number)
    labels = clf.fit_predict(image)
    counts = Counter(labels)
    
    center_colors = clf.cluster_centers_
    ordered_colors = [center_colors[i] for i in counts.keys()]
    hex_colors = [RGB2HEX(ordered_colors[i]) for i in counts.keys()]
    rgb_colors = [webcolors.hex_to_rgb(hex_colors[i]) for i in counts.keys()]

    named_colors = [get_color_name(rgb_colors[i]) for i in counts.keys()]

    values = list(counts.values())
    percentages = []

    for i in values: 
        p = round((i/160000)*100, 0)
        percentages.append(p)

    package = list(zip(hex_colors, named_colors, percentages))
    
    return package

# %%
import pandas as pd

paintings = pd.read_csv('paintings_final.csv')
print(paintings.Object_id.count())
# Out:
# 2652

# %%
painting_colors = {}

#itterate through and get colors for each painting
for index, row in paintings.iterrows():
    #grab the image link and the id
    path = paintings.loc[index, "Met_link"]
    id = paintings.loc[index, "Object_id"]
    
    #get the colors. It returns a list of tuples, which we turn into a list of lists to easier processing later
    try:
        painting_stats = get_colors(get_image(path), 10)
        color_list = [list(elem) for elem in painting_stats]

        painting_colors[id] = color_list
    
        print("Processing painting: " + str(index))
    
    except:
        print("Error in processing painting")
# Out:
# Processing painting: 0
# Processing painting: 1
# Processing painting: 2
# Processing painting: 3
# Processing painting: 4
# Processing painting: 5
# Processing painting: 6
# Processing painting: 7
# Processing painting: 8
# Processing painting: 9
# Processing painting: 10
# Processing painting: 11
# Processing painting: 12
# Processing painting: 13
# Processing painting: 14
# Processing painting: 15
# Processing painting: 16
# Processing painting: 17
# Processing painting: 18
# Processing painting: 19
# Processing painting: 20
# Processing painting: 21
# Processing painting: 22
# Processing painting: 23
# Processing painting: 24
# Processing painting: 25
# Processing painting: 26
# Processing painting: 27
# Processing painting: 28
# Processing painting: 29
# Processing painting: 30
# Processing painting: 31
# Processing painting: 32
# Processing painting: 33
# Processing painting: 34
# Processing painting: 35
# Processing painting: 36
# Processing painting: 37
# Processing painting: 38
# Error in processing painting
# Error in processing painting
# Processing painting: 41
# Processing painting: 42
# Processing painting: 43
# Processing painting: 44
# Processing painting: 45
# Processing painting: 46
# Processing painting: 47
# Processing painting: 48
# Processing painting: 49
# Processing painting: 50
# Processing painting: 51
# Processing painting: 52
# Processing painting: 53
# Processing painting: 54
# Error in processing painting
# Processing painting: 56
# Processing painting: 57
# Processing painting: 58
# Processing painting: 59
# Processing painting: 60
# Processing painting: 61
# Processing painting: 62
# Processing painting: 63
# Processing painting: 64
# Processing painting: 65
# Processing painting: 66
# Error in processing painting
# Processing painting: 68
# Processing painting: 69
# Processing painting: 70
# Processing painting: 71
# Processing painting: 72
# Processing painting: 73
# Processing painting: 74
# Processing painting: 75
# Processing painting: 76
# Processing painting: 77
# Processing painting: 78
# Processing painting: 79
# Processing painting: 80
# Processing painting: 81
# Processing painting: 82
# Processing painting: 83
# Processing painting: 84
# Processing painting: 85
# Processing painting: 86
# Processing painting: 87
# Processing painting: 88
# Processing painting: 89
# Processing painting: 90
# Processing painting: 91
# Processing painting: 92
# Error in processing painting
# Processing painting: 94
# Processing painting: 95
# Processing painting: 96
# Processing painting: 97
# Processing painting: 98
# Processing painting: 99
# Processing painting: 100
# Processing painting: 101
# Processing painting: 102
# Processing painting: 103
# Processing painting: 104
# Processing painting: 105
# Processing painting: 106
# Processing painting: 107
# Processing painting: 108
# Processing painting: 109
# Processing painting: 110
# Processing painting: 111
# Processing painting: 112
# Processing painting: 113
# Processing painting: 114
# Processing painting: 115
# Processing painting: 116
# Processing painting: 117
# Processing painting: 118
# Processing painting: 119
# Processing painting: 120
# Processing painting: 121
# Processing painting: 122
# Processing painting: 123
# Processing painting: 124
# Processing painting: 125
# Processing painting: 126
# Error in processing painting
# Processing painting: 128
# Processing painting: 129
# Processing painting: 130
# Processing painting: 131
# Processing painting: 132
# Processing painting: 133
# Processing painting: 134
# Processing painting: 135
# Processing painting: 136
# Processing painting: 137
# Processing painting: 138
# Processing painting: 139
# Processing painting: 140
# Processing painting: 141
# Processing painting: 142
# Processing painting: 143
# Processing painting: 144
# Processing painting: 145
# Processing painting: 146
# Processing painting: 147
# Processing painting: 148
# Processing painting: 149
# Processing painting: 150
# Processing painting: 151
# Processing painting: 152
# Processing painting: 153
# Processing painting: 154
# Processing painting: 155
# Error in processing painting
# Processing painting: 157
# Processing painting: 158
# Processing painting: 159
# Processing painting: 160
# Processing painting: 161
# Processing painting: 162
# Processing painting: 163
# Processing painting: 164
# Processing painting: 165
# Processing painting: 166
# Processing painting: 167
# Processing painting: 168
# Processing painting: 169
# Error in processing painting
# Processing painting: 171
# Processing painting: 172
# Error in processing painting
# Processing painting: 174
# Processing painting: 175
# Processing painting: 176
# Processing painting: 177
# Processing painting: 178
# Processing painting: 179
# Processing painting: 180
# Processing painting: 181
# Error in processing painting
# Processing painting: 183
# Processing painting: 184
# Processing painting: 185
# Processing painting: 186
# Processing painting: 187
# Processing painting: 188
# Processing painting: 189
# Processing painting: 190
# Processing painting: 191
# Processing painting: 192
# Processing painting: 193
# Processing painting: 194
# Processing painting: 195
# Processing painting: 196
# Processing painting: 197
# Processing painting: 198
# Processing painting: 199
# Processing painting: 200
# Processing painting: 201
# Error in processing painting
# Processing painting: 203
# Processing painting: 204
# Processing painting: 205
# Processing painting: 206
# Processing painting: 207
# Processing painting: 208
# Processing painting: 209
# Processing painting: 210
# Processing painting: 211
# Processing painting: 212
# Processing painting: 213
# Processing painting: 214
# Processing painting: 215
# Processing painting: 216
# Processing painting: 217
# Processing painting: 218
# Processing painting: 219
# Processing painting: 220
# Processing painting: 221
# Processing painting: 222
# Processing painting: 223
# Processing painting: 224
# Processing painting: 225
# Processing painting: 226
# Processing painting: 227
# Processing painting: 228
# Processing painting: 229
# Processing painting: 230
# Processing painting: 231
# Processing painting: 232
# Processing painting: 233
# Processing painting: 234
# Processing painting: 235
# Processing painting: 236
# Processing painting: 237
# Processing painting: 238
# Processing painting: 239
# Processing painting: 240
# Processing painting: 241
# Processing painting: 242
# Processing painting: 243
# Processing painting: 244
# Processing painting: 245
# Processing painting: 246
# Processing painting: 247
# Processing painting: 248
# Processing painting: 249
# Processing painting: 250
# Error in processing painting
# Processing painting: 252
# Processing painting: 253
# Processing painting: 254
# Processing painting: 255
# Processing painting: 256
# Processing painting: 257
# Processing painting: 258
# Processing painting: 259
# Processing painting: 260
# Processing painting: 261
# Processing painting: 262
# Processing painting: 263
# Processing painting: 264
# Processing painting: 265
# Processing painting: 266
# Processing painting: 267
# Processing painting: 268
# Processing painting: 269
# Processing painting: 270
# Processing painting: 271
# Processing painting: 272
# Processing painting: 273
# Processing painting: 274
# Processing painting: 275
# Processing painting: 276
# Processing painting: 277
# Processing painting: 278
# Processing painting: 279
# Processing painting: 280
# Processing painting: 281
# Processing painting: 282
# Processing painting: 283
# Processing painting: 284
# Processing painting: 285
# Processing painting: 286
# Processing painting: 287
# Processing painting: 288
# Processing painting: 289
# Processing painting: 290
# Processing painting: 291
# Processing painting: 292
# Processing painting: 293
# Processing painting: 294
# Processing painting: 295
# Processing painting: 296
# Processing painting: 297
# Error in processing painting
# Processing painting: 299
# Processing painting: 300
# Processing painting: 301
# Processing painting: 302
# Processing painting: 303
# Processing painting: 304
# Processing painting: 305
# Processing painting: 306
# Processing painting: 307
# Processing painting: 308
# Processing painting: 309
# Processing painting: 310
# Processing painting: 311
# Processing painting: 312
# Processing painting: 313
# Processing painting: 314
# Processing painting: 315
# Processing painting: 316
# Processing painting: 317
# Processing painting: 318
# Processing painting: 319
# Processing painting: 320
# Processing painting: 321
# Processing painting: 322
# Processing painting: 323
# Processing painting: 324
# Processing painting: 325
# Processing painting: 326
# Processing painting: 327
# Processing painting: 328
# Processing painting: 329
# Processing painting: 330
# Processing painting: 331
# Processing painting: 332
# Processing painting: 333
# Processing painting: 334
# Processing painting: 335
# Processing painting: 336
# Processing painting: 337
# Processing painting: 338
# Processing painting: 339
# Processing painting: 340
# Processing painting: 341
# Processing painting: 342
# Processing painting: 343
# Processing painting: 344
# Processing painting: 345
# Processing painting: 346
# Processing painting: 347
# Processing painting: 348
# Processing painting: 349
# Processing painting: 350
# Processing painting: 351
# Processing painting: 352
# Processing painting: 353
# Processing painting: 354
# Processing painting: 355
# Processing painting: 356
# Processing painting: 357
# Processing painting: 358
# Processing painting: 359
# Processing painting: 360
# Processing painting: 361
# Processing painting: 362
# Processing painting: 363
# Processing painting: 364
# Processing painting: 365
# Processing painting: 366
# Processing painting: 367
# Processing painting: 368
# Processing painting: 369
# Processing painting: 370
# Processing painting: 371
# Processing painting: 372
# Processing painting: 373
# Processing painting: 374
# Processing painting: 375
# Processing painting: 376
# Processing painting: 377
# Processing painting: 378
# Processing painting: 379
# Processing painting: 380
# Processing painting: 381
# Processing painting: 382
# Processing painting: 383
# Processing painting: 384
# Processing painting: 385
# Processing painting: 386
# Processing painting: 387
# Processing painting: 388
# Processing painting: 389
# Processing painting: 390
# Processing painting: 391
# Processing painting: 392
# Processing painting: 393
# Processing painting: 394
# Processing painting: 395
# Processing painting: 396
# Processing painting: 397
# Processing painting: 398
# Processing painting: 399
# Processing painting: 400
# Processing painting: 401
# Processing painting: 402
# Processing painting: 403
# Processing painting: 404
# Processing painting: 405
# Processing painting: 406
# Processing painting: 407
# Processing painting: 408
# Error in processing painting
# Processing painting: 410
# Processing painting: 411
# Processing painting: 412
# Processing painting: 413
# Processing painting: 414
# Processing painting: 415
# Processing painting: 416
# Processing painting: 417
# Processing painting: 418
# Processing painting: 419
# Processing painting: 420
# Processing painting: 421
# Processing painting: 422
# Processing painting: 423
# Processing painting: 424
# Processing painting: 425
# Processing painting: 426
# Processing painting: 427
# Processing painting: 428
# Processing painting: 429
# Processing painting: 430
# Processing painting: 431
# Processing painting: 432
# Processing painting: 433
# Processing painting: 434
# Processing painting: 435
# Processing painting: 436
# Error in processing painting
# Processing painting: 438
# Processing painting: 439
# Processing painting: 440
# Processing painting: 441
# Processing painting: 442
# Processing painting: 443
# Processing painting: 444
# Processing painting: 445
# Processing painting: 446
# Processing painting: 447
# Processing painting: 448
# Processing painting: 449
# Processing painting: 450
# Processing painting: 451
# Processing painting: 452
# Processing painting: 453
# Processing painting: 454
# Processing painting: 455
# Processing painting: 456
# Processing painting: 457
# Processing painting: 458
# Processing painting: 459
# Processing painting: 460
# Processing painting: 461
# Processing painting: 462
# Processing painting: 463
# Processing painting: 464
# Processing painting: 465
# Processing painting: 466
# Processing painting: 467
# Processing painting: 468
# Processing painting: 469
# Processing painting: 470
# Processing painting: 471
# Processing painting: 472
# Processing painting: 473
# Processing painting: 474
# Processing painting: 475
# Processing painting: 476
# Processing painting: 477
# Processing painting: 478
# Processing painting: 479
# Processing painting: 480
# Processing painting: 481
# Processing painting: 482
# Processing painting: 483
# Processing painting: 484
# Processing painting: 485
# Processing painting: 486
# Processing painting: 487
# Processing painting: 488
# Processing painting: 489
# Processing painting: 490
# Processing painting: 491
# Processing painting: 492
# Processing painting: 493
# Processing painting: 494
# Processing painting: 495
# Processing painting: 496
# Processing painting: 497
# Processing painting: 498
# Processing painting: 499
# Processing painting: 500
# Processing painting: 501
# Processing painting: 502
# Processing painting: 503
# Processing painting: 504
# Processing painting: 505
# Processing painting: 506
# Processing painting: 507
# Processing painting: 508
# Processing painting: 509
# Processing painting: 510
# Processing painting: 511
# Processing painting: 512
# Processing painting: 513
# Processing painting: 514
# Processing painting: 515
# Processing painting: 516
# Processing painting: 517
# Processing painting: 518
# Processing painting: 519
# Processing painting: 520
# Processing painting: 521
# Processing painting: 522
# Processing painting: 523
# Processing painting: 524
# Processing painting: 525
# Processing painting: 526
# Processing painting: 527
# Processing painting: 528
# Processing painting: 529
# Processing painting: 530
# Processing painting: 531
# Processing painting: 532
# Processing painting: 533
# Processing painting: 534
# Processing painting: 535
# Processing painting: 536
# Processing painting: 537
# Processing painting: 538
# Processing painting: 539
# Processing painting: 540
# Processing painting: 541
# Processing painting: 542
# Processing painting: 543
# Processing painting: 544
# Processing painting: 545
# Processing painting: 546
# Processing painting: 547
# Processing painting: 548
# Processing painting: 549
# Processing painting: 550
# Processing painting: 551
# Processing painting: 552
# Processing painting: 553
# Processing painting: 554
# Processing painting: 555
# Processing painting: 556
# Processing painting: 557
# Error in processing painting
# Processing painting: 559
# Processing painting: 560
# Processing painting: 561
# Processing painting: 562
# Processing painting: 563
# Processing painting: 564
# Processing painting: 565
# Processing painting: 566
# Processing painting: 567
# Processing painting: 568
# Processing painting: 569
# Processing painting: 570
# Processing painting: 571
# Processing painting: 572
# Processing painting: 573
# Processing painting: 574
# Processing painting: 575
# Processing painting: 576
# Processing painting: 577
# Error in processing painting
# Processing painting: 579
# Processing painting: 580
# Processing painting: 581
# Processing painting: 582
# Processing painting: 583
# Processing painting: 584
# Processing painting: 585
# Processing painting: 586
# Processing painting: 587
# Processing painting: 588
# Processing painting: 589
# Processing painting: 590
# Processing painting: 591
# Processing painting: 592
# Error in processing painting
# Processing painting: 594
# Processing painting: 595
# Processing painting: 596
# Processing painting: 597
# Processing painting: 598
# Processing painting: 599
# Processing painting: 600
# Processing painting: 601
# Processing painting: 602
# Processing painting: 603
# Processing painting: 604
# Processing painting: 605
# Processing painting: 606
# Processing painting: 607
# Processing painting: 608
# Processing painting: 609
# Processing painting: 610
# Processing painting: 611
# Processing painting: 612
# Processing painting: 613
# Processing painting: 614
# Processing painting: 615
# Processing painting: 616
# Processing painting: 617
# Processing painting: 618
# Processing painting: 619
# Processing painting: 620
# Processing painting: 621
# Processing painting: 622
# Error in processing painting
# Processing painting: 624
# Processing painting: 625
# Processing painting: 626
# Processing painting: 627
# Processing painting: 628
# Processing painting: 629
# Processing painting: 630
# Processing painting: 631
# Processing painting: 632
# Processing painting: 633
# Processing painting: 634
# Processing painting: 635
# Processing painting: 636
# Processing painting: 637
# Processing painting: 638
# Processing painting: 639
# Processing painting: 640
# Error in processing painting
# Processing painting: 642
# Processing painting: 643
# Processing painting: 644
# Processing painting: 645
# Processing painting: 646
# Processing painting: 647
# Processing painting: 648
# Processing painting: 649
# Processing painting: 650
# Processing painting: 651
# Processing painting: 652
# Processing painting: 653
# Processing painting: 654
# Error in processing painting
# Processing painting: 656
# Processing painting: 657
# Processing painting: 658
# Processing painting: 659
# Processing painting: 660
# Processing painting: 661
# Processing painting: 662
# Processing painting: 663
# Processing painting: 664
# Processing painting: 665
# Processing painting: 666
# Processing painting: 667
# Processing painting: 668
# Processing painting: 669
# Processing painting: 670
# Processing painting: 671
# Processing painting: 672
# Processing painting: 673
# Processing painting: 674
# Processing painting: 675
# Processing painting: 676
# Processing painting: 677
# Processing painting: 678
# Processing painting: 679
# Processing painting: 680
# Processing painting: 681
# Processing painting: 682
# Processing painting: 683
# Processing painting: 684
# Processing painting: 685
# Processing painting: 686
# Processing painting: 687
# Processing painting: 688
# Processing painting: 689
# Processing painting: 690
# Processing painting: 691
# Processing painting: 692
# Processing painting: 693
# Processing painting: 694
# Processing painting: 695
# Processing painting: 696
# Processing painting: 697
# Processing painting: 698
# Processing painting: 699
# Processing painting: 700
# Processing painting: 701
# Processing painting: 702
# Processing painting: 703
# Processing painting: 704
# Processing painting: 705
# Processing painting: 706
# Processing painting: 707
# Processing painting: 708
# Processing painting: 709
# Processing painting: 710
# Processing painting: 711
# Processing painting: 712
# Processing painting: 713
# Processing painting: 714
# Processing painting: 715
# Processing painting: 716
# Processing painting: 717
# Processing painting: 718
# Processing painting: 719
# Processing painting: 720
# Processing painting: 721

# %%
#Create new table, then melt so that each color pair is a unique row with it's assigned (repeating) index
colors = pd.DataFrame.from_dict(painting_colors, orient='index')
colors = colors.reset_index()
colors = pd.melt(colors, id_vars = ["index"])

print(colors["index"].nunique())
print(colors["index"].count())
colors.head()

# %%
colors["value"] = colors["value"].astype(str)

split_colors = colors["value"].str.split(",", expand = True) 
colors["Hex"] = split_colors[0].str.strip("[ '")
colors["Color name"] = split_colors[1].str.strip("' ''")
colors["Size"] = split_colors[2].str.strip("]")

colors = colors.drop(columns=["variable", "value"])
colors = colors.rename(columns = {'index':"Object_id"})

# %%
colors.head()

# %%
colors.to_csv('paintings_colors.csv', index = False)
